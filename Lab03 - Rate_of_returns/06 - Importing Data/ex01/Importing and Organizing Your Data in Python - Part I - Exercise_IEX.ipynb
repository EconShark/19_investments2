# %% [markdown]
# ## Importing and Organizing Your Data in Python - Part I

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# a. Create a series object of 10 randomly generated integer values.

# %%
import numpy as np
import pandas as pd

series1 = pd.Series(np.random.random(10), name = "Series 1")

# %%
series1
# Out:
# 0    0.791673
# 1    0.460861
# 2    0.539420
# 3    0.948644
# 4    0.088337
# 5    0.488434
# 6    0.170482
# 7    0.900261
# 8    0.920504
# 9    0.675491
# Name: Series 1, dtype: float64

# %%
series1[2:5]
# Out:
# 2    0.539420
# 3    0.948644
# 4    0.088337
# Name: Series 1, dtype: float64

# %% [markdown]
# b. Extract data from IEX for Ford from the 1st of January 2015. The ticker you need is ‘F’.
