# %% [markdown]
# ## Simpler Returns - Part I

# %% [markdown]
# Download the data for Microsoft (‘MSFT’) from Yahoo Finance for the period ‘2000-1-1’ until today.

# %%
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
MSFT = yf.download(
    "MSFT",
    start="2000-01-01",
    auto_adjust=True
)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Apply the .**head()** and **.tail()** methods to check if the data is ok. Always pay attention to the dates. Try to get an idea about how the stock price changed during the period.

# %%
print(MSFT.head())
# Out:
# Price           Close       High        Low       Open    Volume
# Ticker           MSFT       MSFT       MSFT       MSFT      MSFT
# Date
# 2000-01-03  35.443607  36.070760  34.056270  35.690667  53228400
# 2000-01-04  34.246334  35.614667  34.132306  34.531403  54119000
# 2000-01-05  34.607414  35.386604  33.258086  33.790216  64059600
# 2000-01-06  33.448116  34.626402  32.953996  34.113278  54976600
# 2000-01-07  33.885242  34.132303  32.630937  33.030034  62013600

# %%
print(MSFT.tail())
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2026-05-22  418.570007  424.399994  416.329987  419.540009  22390300
# 2026-05-26  416.029999  419.769989  413.019989  416.429993  30398000
# 2026-05-27  412.670013  415.940002  409.579987  411.010010  28901500
# 2026-05-28  426.989990  429.489990  412.670013  412.980011  47250500
# 2026-05-29  450.239990  450.329987  432.359985  432.549988  79522600

# %% [markdown]
# ### Simple Rate of Return

# %% [markdown]
# Calculate the simple returns of ‘MSFT’ for the given timeframe.

# %% [markdown]
# $$
# \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1
# $$

# %%
#MSFT["Simple Return"] = MSFT["Close"].pct_change()
MSFT["Simple Return"] = MSFT["Close"]/MSFT["Close"].shift(1) - 1
print(MSFT["Simple Return"])
# Out:
# Date
# 2000-01-03         NaN
# 2000-01-04   -0.033780
# 2000-01-05    0.010544
# 2000-01-06   -0.033499
# 2000-01-07    0.013069
#                 ...
# 2026-05-22   -0.001241
# 2026-05-26   -0.006068
# 2026-05-27   -0.008076
# 2026-05-28    0.034701
# 2026-05-29    0.054451
# Name: Simple Return, Length: 6641, dtype: float64
